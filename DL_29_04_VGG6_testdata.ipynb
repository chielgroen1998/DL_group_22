# %% [markdown]
# <a href="https://colab.research.google.com/github/chielgroen1998/DL_group_22/blob/main/DL_29_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown
# !pip install tensorflow
# !pip install --upgrade opencv-python
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)

# %%
import os
import zipfile
import numpy as np
import pandas as pd
from PIL import Image
import tensorflow as tf
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import sklearn.model_selection
import random
from tensorflow.keras import layers, Model
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc, f1_score
from sklearn.preprocessing import label_binarize

# %%
# To download the file
file_id = "1el92N8lBia2a5RFK0leeFQFRyhsEXaZx"
#file_id = "1PyxqW_nsORX4PetkQo6OIL0mUL1pFsTD"
# !gdown --id {file_id} -O rare_species.zip
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1el92N8lBia2a5RFK0leeFQFRyhsEXaZx
# From (redirected): https://drive.google.com/uc?id=1el92N8lBia2a5RFK0leeFQFRyhsEXaZx&confirm=t&uuid=266f7a41-3178-49b8-beca-a64a98788122
# To: /content/rare_species.zip
# 100% 4.26G/4.26G [00:33<00:00, 129MB/s]

# %%
# Verify file size
# !ls -lh rare_species.zip
# Out:
# -rw-r--r-- 1 root root 4.0G Apr 11 12:01 rare_species.zip

# %%
# File extraction
extract_path = '/content/rare_species'
if not os.path.exists(extract_path):
    os.makedirs(extract_path)
    print(f"Created directory: {extract_path}")

print("Extracting zip ")
with zipfile.ZipFile('rare_species.zip', 'r') as zip_ref:
    zip_ref.extractall(extract_path)
print("Extraction complete")
# Out:
# Created directory: /content/rare_species
# Extracting zip
# Extraction complete

# %%
# List fo contents for double-check
# !ls -la {extract_path}
# Out:
# total 2928
# drwxr-xr-x 204 root root   12288 Apr 30 20:35 .
# drwxr-xr-x   1 root root    4096 Apr 30 20:35 ..
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 arthropoda_apidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_attelabidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_carabidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_cerambycidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_coenagrionidae
# drwxr-xr-x   2 root root   20480 Apr 30 20:35 arthropoda_formicidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_gomphidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_lucanidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_nymphalidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_palinuridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_papilionidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_pisauridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_platystictidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_pseudophasmatidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_tettigoniidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_theraphosidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 arthropoda_triopsidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_accipitridae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_acipenseridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_agamidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_albulidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_alcedinidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_alligatoridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_alopiidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_ambystomatidae
# drwxr-xr-x   2 root root   20480 Apr 30 20:35 chordata_anatidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_anguidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_aotidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_ardeidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_arthroleptidae
# drwxr-xr-x   2 root root   16384 Apr 30 20:35 chordata_atelidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_balaenicipitidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_balaenidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_balaenopteridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_balistidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_bombycillidae
# drwxr-xr-x   2 root root   20480 Apr 30 20:35 chordata_bovidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_brachypteraciidae
# drwxr-xr-x   2 root root   20480 Apr 30 20:35 chordata_bucerotidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_bufonidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_burhinidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_cacatuidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_callitrichidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_callorhinchidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_caprimulgidae
# drwxr-xr-x   2 root root   20480 Apr 30 20:35 chordata_carcharhinidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_carettochelyidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_cebidae
# drwxr-xr-x   2 root root   20480 Apr 30 20:35 chordata_cercopithecidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_cervidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_cetorhinidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_chaetodontidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_chamaeleonidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_charadriidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_cheirogaleidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_chelidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_cheloniidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_chelydridae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_ciconiidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_colubridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_columbidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_cracidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_cricetidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_crocodylidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_cryptobranchidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_ctenomyidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_cuculidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_cyprinodontidae
# drwxr-xr-x   2 root root   20480 Apr 30 20:35 chordata_dactyloidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_dalatiidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_dasyatidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_dasypodidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_dasyuridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_daubentoniidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_delphinidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_dendrobatidae
# drwxr-xr-x   2 root root   20480 Apr 30 20:35 chordata_diomedeidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_diplodactylidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_elapidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_emydidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_equidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_estrildidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_falconidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_fringillidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_gavialidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_gekkonidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_geoemydidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_giraffidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_glareolidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_gliridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_goodeidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_gymnuridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_hemiscylliidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_hexanchidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_hominidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_hyaenidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_hylobatidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_hynobiidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_iguanidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_indriidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_labridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_lacertidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_lamnidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_laridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_latimeriidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_lemuridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_leporidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_lutjanidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_manidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_mantellidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_megapodiidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_merlucciidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_mesitornithidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_mimidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_motacillidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_muscicapidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_mustelidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_myliobatidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_nesospingidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_odontophoridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_otariidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_otididae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_pangasiidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_paradisaeidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_pardalotidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_parulidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_percidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_phasianidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_phrynosomatidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_phyllomedusidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_phyllostomidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_pittidae
# drwxr-xr-x   2 root root   20480 Apr 30 20:35 chordata_plethodontidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_pleuronectidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_podocnemididae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_polyprionidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_pontoporiidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_potoroidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_pristidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_procellariidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_psittacidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_psittaculidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_pythonidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_rajidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_rallidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_ramphastidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_ranidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_recurvirostridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_rhacophoridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_rhinodermatidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_rhyacotritonidae
# drwxr-xr-x   2 root root   20480 Apr 30 20:35 chordata_salamandridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_salmonidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_scincidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_sciuridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_scolopacidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_scombridae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_serranidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_siluridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_somniosidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_soricidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_sparidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_spheniscidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_sphyrnidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_squalidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_squatinidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_strigidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_strigopidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_syngnathidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_testudinidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_thraupidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_trionychidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 chordata_trochilidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_trogonidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_tropiduridae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_turdidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_urolophidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_ursidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_vangidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_vespertilionidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_viperidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_vireonidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 chordata_vombatidae
# drwxr-xr-x   2 root root   20480 Apr 30 20:35 cnidaria_acroporidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 cnidaria_agariciidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 cnidaria_dendrophylliidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 cnidaria_diploastraeidae
# drwxr-xr-x   2 root root   12288 Apr 30 20:35 cnidaria_euphylliidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 cnidaria_faviidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 cnidaria_fungiidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 cnidaria_helioporidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 cnidaria_lobophylliidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 cnidaria_meandrinidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 cnidaria_merulinidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 cnidaria_pocilloporidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 cnidaria_siderastreidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 echinodermata_stichopodidae
# -rw-r--r--   1 root root 1740606 Apr 30 20:35 metadata.csv
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 mollusca_cardiidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 mollusca_conidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 mollusca_haliotidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 mollusca_unionidae
# drwxr-xr-x   2 root root    4096 Apr 30 20:35 mollusca_zonitidae

# %%
# To load the csv file as metadata
csv_files = [f for f in os.listdir(extract_path) if f.endswith('.csv')]
print(f"Found CSV files: {csv_files}")

if csv_files:
    metadata_path = os.path.join(extract_path, csv_files[0])
    metadata = pd.read_csv(metadata_path)
    print(f"Loaded metadata with shape: {metadata.shape}")
    print(metadata.head())
else:
    print("No CSV file found.")
# Out:
# Found CSV files: ['metadata.csv']
# Loaded metadata with shape: (11983, 7)
#                         rare_species_id  eol_content_id  eol_page_id  \
# 0  75fd91cb-2881-41cd-88e6-de451e8b60e2        12853737       449393
# 1  28c508bc-63ff-4e60-9c8f-1934367e1528        20969394       793083
# 2  00372441-588c-4af8-9665-29bee20822c0        28895411       319982
# 3  29cc6040-6af2-49ee-86ec-ab7d89793828        29658536     45510188
# 4  94004bff-3a33-4758-8125-bf72e6e57eab        21252576      7250886
#
#     kingdom    phylum            family  \
# 0  animalia  mollusca         unionidae
# 1  animalia  chordata       geoemydidae
# 2  animalia  chordata  cryptobranchidae
# 3  animalia  chordata          turdidae
# 4  animalia  chordata         indriidae
#
#                                            file_path
# 0  mollusca_unionidae/12853737_449393_eol-full-si...
# 1  chordata_geoemydidae/20969394_793083_eol-full-...
# 2  chordata_cryptobranchidae/28895411_319982_eol-...
# 3  chordata_turdidae/29658536_45510188_eol-full-s...
# 4  chordata_indriidae/21252576_7250886_eol-full-s...

# %% [markdown]
# # EDA

# %% [markdown]
# ## Metadata

# %%
# check data head
metadata.head(20)
# Out:
#                          rare_species_id  eol_content_id  eol_page_id  \
# 0   75fd91cb-2881-41cd-88e6-de451e8b60e2        12853737       449393
# 1   28c508bc-63ff-4e60-9c8f-1934367e1528        20969394       793083
# 2   00372441-588c-4af8-9665-29bee20822c0        28895411       319982
# 3   29cc6040-6af2-49ee-86ec-ab7d89793828        29658536     45510188
# 4   94004bff-3a33-4758-8125-bf72e6e57eab        21252576      7250886
# 5   dc48f2ce-4feb-4ef7-b2a2-c3c3f42bf19b        28657539       491832
# 6   3d881320-8ba8-4580-a72c-0e7ab116b664        29548208     47043290
# 7   7faca96a-54e6-4c80-b9e4-77ab126d904a        21232818      1033999
# 8   9f89ecab-aabd-41a4-b5b4-8ce106d85959        20315204     46561012
# 9   b6ec7a70-c470-4ede-8930-05844e1efd2e        20124498     46570095
# 10  309ead66-8bb3-4043-a372-3bf353ab328c        28209894     45510504
# 11  a6ca8369-a94f-416d-8ad4-d04d6473c611        29369182       323726
# 12  50beb29b-c7f0-474c-8562-dce68b035708        30053716       912805
# 13  fa538ef6-0709-4c39-a85b-12d3e9f7cd09        28264284     46561012
# 14  86f66e77-6967-4559-9cae-50652872fd0a        20599608     45513966
# 15  a8e04499-9757-408f-80cd-4e508dc3b8f2        22662179     45511624
# 16  e09db146-4447-4863-a0cf-23b85c4cf293        29898060     46559814
# 17  0b31111b-ab31-45a2-b547-0f0a8f212f0a        21780197     45511494
# 18  7a7d7140-b981-4ec5-8a62-34d0d6a54dae        29297287       794627
# 19  1654b5d4-1bca-405d-9b83-b4aa569316fb        22743125      1048224
#
#      kingdom      phylum            family  \
# 0   animalia    mollusca         unionidae
# 1   animalia    chordata       geoemydidae
# 2   animalia    chordata  cryptobranchidae
# 3   animalia    chordata          turdidae
# 4   animalia    chordata         indriidae
# 5   animalia  arthropoda        formicidae
# 6   animalia    chordata      fringillidae
# 7   animalia  arthropoda         gomphidae
# 8   animalia    chordata      myliobatidae
# 9   animalia    chordata    pleuronectidae
# 10  animalia    chordata     nesospingidae
# 11  animalia    chordata        dasyuridae
# 12  animalia    chordata      accipitridae
# 13  animalia    chordata      myliobatidae
# 14  animalia    chordata       glareolidae
# 15  animalia    chordata        trogonidae
# 16  animalia    chordata    carcharhinidae
# 17  animalia    chordata       diomedeidae
# 18  animalia    chordata        gavialidae
# 19  animalia    chordata     salamandridae
#
#                                             file_path
# 0   mollusca_unionidae/12853737_449393_eol-full-si...
# 1   chordata_geoemydidae/20969394_793083_eol-full-...
# 2   chordata_cryptobranchidae/28895411_319982_eol-...
# 3   chordata_turdidae/29658536_45510188_eol-full-s...
# 4   chordata_indriidae/21252576_7250886_eol-full-s...
# 5   arthropoda_formicidae/28657539_491832_eol-full...
# 6   chordata_fringillidae/29548208_47043290_eol-fu...
# 7   arthropoda_gomphidae/21232818_1033999_eol-full...
# 8   chordata_myliobatidae/20315204_46561012_eol-fu...
# 9   chordata_pleuronectidae/20124498_46570095_eol-...
# 10  chordata_nesospingidae/28209894_45510504_eol-f...
# 11  chordata_dasyuridae/29369182_323726_eol-full-s...
# 12  chordata_accipitridae/30053716_912805_eol-full...
# 13  chordata_myliobatidae/28264284_46561012_eol-fu...
# 14  chordata_glareolidae/20599608_45513966_eol-ful...
# 15  chordata_trogonidae/22662179_45511624_eol-full...
# 16  chordata_carcharhinidae/29898060_46559814_eol-...
# 17  chordata_diomedeidae/21780197_45511494_eol-ful...
# 18  chordata_gavialidae/29297287_794627_eol-full-s...
# 19  chordata_salamandridae/22743125_1048224_eol-fu...

# %%
#check data properties
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11983 entries, 0 to 11982
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rare_species_id  11983 non-null  object
#  1   eol_content_id   11983 non-null  int64
#  2   eol_page_id      11983 non-null  int64
#  3   kingdom          11983 non-null  object
#  4   phylum           11983 non-null  object
#  5   family           11983 non-null  object
#  6   file_path        11983 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 655.4+ KB

# %% [markdown]
# Our dataset is composed of 11983 entries and 7 columns, where the datatypes are objects and integers.

# %%
# check class frequency
metadata.describe(include="object")
# Out:
#                              rare_species_id   kingdom    phylum       family  \
# count                                  11983     11983     11983        11983
# unique                                 11983         1         5          202
# top     54894a59-151f-4814-ac32-3a336841e58e  animalia  chordata  dactyloidae
# freq                                       1     11983      9952          300
#
#                                                 file_path
# count                                               11983
# unique                                              11983
# top     chordata_lemuridae/9465817_326525_eol-full-siz...
# freq                                                    1

# %% [markdown]
# "chordata"and "dactyloidae" are the most frequent phylum type and family type respectively with 9952	and 300 entries.

# %%
# check missing values
metadata.isnull().sum()
# Out:
# rare_species_id    0
# eol_content_id     0
# eol_page_id        0
# kingdom            0
# phylum             0
# family             0
# file_path          0
# dtype: int64

# %% [markdown]
# No missing values are found, which facilitate the tabular data treatment

# %%
# check duplicates that might need to be dropped
print("number of duplicate in the dataset :", metadata.duplicated().sum())
print("number of duplicate in 'rare_species_id' :", metadata.duplicated(subset=['rare_species_id']).sum())
print("number of duplicate 'file_path' :", metadata.duplicated(subset=['file_path']).sum())
# Out:
# number of duplicate in the dataset : 0
# number of duplicate in 'rare_species_id' : 0
# number of duplicate 'file_path' : 0

# %%
# check all duplicates
metadata.nunique()
# Out:
# rare_species_id    11983
# eol_content_id     11983
# eol_page_id          400
# kingdom                1
# phylum                 5
# family               202
# file_path          11983
# dtype: int64

# %% [markdown]
# "rare_species_id", "eol_content_id", and "file_path" appear to have unique observations for each entry, while "eol_page_id", "family", "kingdom" and "phylum" have less. As we do not need the unique IDs, we drop them along the kingdom as they do not provide any information to our model.

# %%
# Drop unecessary columns
columns_to_keep = ['file_path', 'eol_page_id', 'family', 'phylum']
metadata = metadata[columns_to_keep]
print('Colonnes restantes:', metadata.columns.tolist())
# Out:
# Colonnes restantes: ['file_path', 'eol_page_id', 'family', 'phylum']

# %%
metadata.head()
# Out:
#                                            file_path  eol_page_id  \
# 0  mollusca_unionidae/12853737_449393_eol-full-si...       449393
# 1  chordata_geoemydidae/20969394_793083_eol-full-...       793083
# 2  chordata_cryptobranchidae/28895411_319982_eol-...       319982
# 3  chordata_turdidae/29658536_45510188_eol-full-s...     45510188
# 4  chordata_indriidae/21252576_7250886_eol-full-s...      7250886
#
#              family    phylum
# 0         unionidae  mollusca
# 1       geoemydidae  chordata
# 2  cryptobranchidae  chordata
# 3          turdidae  chordata
# 4         indriidae  chordata

# %% [markdown]
# ##Class Disribution Analysis

# %%
# defining processed data directory and raw data_dir
DATA_DIR = '/content/rare_species'
processed_data_path = '/content/processed_data'

if not os.path.exists(processed_data_path):
    os.makedirs(processed_data_path)

# image distribution by family
if 'family' in metadata.columns:
    family_counts = metadata['family'].value_counts()
    print(f"Number of unique families: {len(family_counts)}")
    print("Top 10 most common families:")
    print(family_counts.head(10))

    # family distribution plot
    plt.figure(figsize=(12, 6))
    family_counts.head(20).plot(kind='bar')
    plt.title('Distribution of Top 20 Families')
    plt.xlabel('Family')
    plt.ylabel('Count')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()
# Out:
# Number of unique families: 202
# Top 10 most common families:
# family
# dactyloidae        300
# cercopithecidae    300
# formicidae         291
# carcharhinidae     270
# salamandridae      270
# plethodontidae     270
# bovidae            240
# bucerotidae        210
# acroporidae        210
# diomedeidae        180
# Name: count, dtype: int64

# %% [markdown]
# The bar chart shows the 20 most frequent families, where Dactyloidae, Cercopithecidae, and Formicidae appears as the dominant families with over 290 image each. As we have 11983 images, and half of them are distributed over 3 families, this means that we have a class imbalance.

# %%
# now we check image distribution by phylum
if 'phylum' in metadata.columns:
    phylum_counts = metadata['phylum'].value_counts()
    print(f"Number of unique phylums: {len(phylum_counts)}")
    print("phylum distribution:")
    print(phylum_counts.head())

    # phylum distribution plot
    plt.figure(figsize=(12, 6))
    phylum_counts.plot(kind='bar')
    plt.title('Distribution by phylum')
    plt.xlabel('phylum')
    plt.ylabel('Count')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()
# Out:
# Number of unique phylums: 5
# phylum distribution:
# phylum
# chordata         9952
# arthropoda        951
# cnidaria          810
# mollusca          210
# echinodermata      60
# Name: count, dtype: int64

# %% [markdown]
# This bar chart shows that chrodata is the dominant phylum type of the 5 classes, while Echinodermata is close to 0. If we further want to use phylum as an output, we might need to consider balancing the classes.

# %%
# Make a table to see how families are spread across each phylum
pivot_table = pd.pivot_table(metadata,
                             index='phylum',
                             columns='family',
                             aggfunc='size',
                             fill_value=0)

print(f"Total number of images : {pivot_table.values.sum()}")
print("Total number of families :")
print(pivot_table.astype(bool).sum(axis=1))  # Counts how many families each phylum has

# Show a heatmap of the distribution
plt.figure(figsize=(15, 5))
sns.heatmap(pivot_table, cmap='Blues', annot=False)
plt.title('Distribution of families by phylum')
plt.xlabel('Family')
plt.ylabel('Phylum')
plt.tight_layout()
plt.show()
# Out:
# Total number of images : 11983
# Total number of families :
# phylum
# arthropoda        17
# chordata         166
# cnidaria          13
# echinodermata      1
# mollusca           5
# dtype: int64

# %% [markdown]
# The heatmap shows the distribution of families across the different phylum types, where the chordata appears to hold most families as expected from the previous chart.

# %% [markdown]
# ##Image Quality and Resolution check

# %%
if 'file_path' in metadata.columns:
    # Analyze image dimensions
    resolutions = []
    formats = []

    for idx, row in metadata.iterrows():
        img_path = os.path.join(DATA_DIR, row['file_path'])
        try:
            with Image.open(img_path) as img:
                resolutions.append(img.size)
                formats.append(img.format)
        except:
            continue

    # Calculate statistics
    unique_resolutions = pd.Series(resolutions).value_counts()
    width, height = zip(*resolutions)

    print("\nImage Resolution Analysis:")
    print(f"Unique resolutions: {len(unique_resolutions)}")
    print(f"Average width: {np.mean(width):.1f} ± {np.std(width):.1f}")
    print(f"Average height: {np.mean(height):.1f} ± {np.std(height):.1f}")
    print("\nFormat distribution:")
    print(pd.Series(formats).value_counts())

    # Visualize resolution distribution
    plt.figure(figsize=(12, 6))
    plt.scatter(width, height, alpha=0.5)
    plt.title('Image Resolution Distribution')
    plt.xlabel('Width')
    plt.ylabel('Height')
    plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3442: DecompressionBombWarning: Image size (115600000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# Image Resolution Analysis:
# Unique resolutions: 5229
# Average width: 1924.6 ± 1267.5
# Average height: 1512.3 ± 951.3
#
# Format distribution:
# JPEG    11983
# Name: count, dtype: int64

# %% [markdown]
# Most of the images are on the smaller side—less than 5000 pixels wide and 3000 pixels tall. A few images are much bigger, with some as wide as 17,500 pixels. In general, wider images also tend to be taller, which makes sense. There seem to be a few different groups of image sizes, which might mean they came from different sources or were taken in different ways.

# %% [markdown]
# ##Color Distribution Across Species

# %%
if 'family' in metadata.columns:
    # Calculate color statistics
    color_stats = []

    for idx, row in metadata.iterrows():
        img_path = os.path.join(DATA_DIR, row['file_path'])
        try:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            color_stats.append({
                'family': row['family'],
                'mean_r': np.mean(img[:,:,0]),
                'mean_g': np.mean(img[:,:,1]),
                'mean_b': np.mean(img[:,:,2])
            })
        except:
            continue

    color_df = pd.DataFrame(color_stats)

    # color distributionp plot for the 5 most frequent families
    plt.figure(figsize=(15, 5))
    for i, channel in enumerate(['mean_r', 'mean_g', 'mean_b']):
        plt.subplot(1, 3, i+1)
        for family in color_df['family'].unique()[:5]:
            sns.kdeplot(color_df[color_df['family'] == family][channel], label=family)
        plt.title(f'{channel.upper()} Distribution')
        plt.xlabel('Intensity')
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# The three density plots represent the distributions of red, green, and blue channel intensities across the five most frequent families. Most families show peak intensity values between 100 and 150. However, we can notice a few differences, ex:
# - Indriidae shows a sharp and narrow peak in all three channels density, which reflects consistent coloration across its images.
# - Cryptobranchidae has broader distributions with higher intensities, especially in the red and green channels, which reflects more color variation or brighter images.
#
# We suppose that these variations in density and intensity are due to differences in the animals' natural coloration, their environments, or how the images were captured (e.g., lighting, cameras, etc.).
# This color imbalance suggests the usage of augmentation so that the model could learn equitably.

# %% [markdown]
# ##Shape & Texture features

# %%
plt.figure(figsize=(15, 10))
for i, (idx, row) in enumerate(metadata.iterrows(), 1):  # iterate through ALL rows, might take around 40mins to run
    img_path = os.path.join(DATA_DIR, row['file_path'])
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

    plt.subplot(len(metadata), 2, i*2-1)
    plt.imshow(img, cmap='gray')
    plt.title(f'Original: {row["family"]}')

# edge detection

    edges = cv2.Canny(img, 100, 200)
    plt.subplot(len(metadata), 2, i*2)
    plt.imshow(edges, cmap='gray')
    plt.title('Edge Detection')

plt.tight_layout()
plt.show()

# texture analysis

texture_features = []
for idx, row in metadata.iterrows():
    img_path = os.path.join(DATA_DIR, row['file_path'])
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is not None:
        texture_features.append({
            'family': row['family'],
            'contrast': feature.greycoprops(feature.greycomatrix(img, [1], [0]), 'contrast')[0][0],
            'entropy': shannon_entropy(img)
        })

texture_df = pd.DataFrame(texture_features)

# texture features plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='family', y='contrast', data=texture_df[texture_df['family'].isin(texture_df['family'].value_counts().index[:5])])
plt.title('Texture Contrast Distribution by Family')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-dc2d978f594a> in <cell line: 0>()
#      10 # edge detection
#      11
# ---> 12     edges = cv2.Canny(img, 100, 200)
#      13     plt.subplot(len(metadata), 2, i*2)
#      14     plt.imshow(edges, cmap='gray')
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x7c38833a6f20> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#     280
#     281
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     129         for manager in cls.get_all_fig_managers():
#     130             if force or manager.canvas.figure.stale:
# --> 131                 manager.canvas.draw_idle()
#     132
#     133
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1889         if not self._is_idle_drawing:
#    1890             with self._idle_draw_cntx():
# -> 1891                 self.draw(*args, **kwargs)
#    1892
#    1893     @property
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     380         with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381               else nullcontext()):
# --> 382             self.figure.draw(self.renderer)
#     383             # A GUI class may be need to update a window using this draw, so
#     384             # don't forget to call the superclass.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3179             _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
#    3180
# -> 3181         mimage._draw_list_compositing_images(
#    3182             renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3183
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in draw(self, renderer)
#     597                 renderer.draw_image(gc, l, b, im, trans)
#     598         else:
# --> 599             im, l, b, trans = self.make_image(
#     600                 renderer, renderer.get_image_magnification())
#     601             if im is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     900         clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     901                 else self.get_figure(root=True).bbox)
# --> 902         return self._make_image(self._A, bbox, transformed_bbox, clip,
#     903                                 magnification, unsampled=unsampled)
#     904
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     511                     output_alpha = _resample(  # resample alpha channel
#     512                         self, A[..., 3], out_shape, t, alpha=alpha)
# --> 513                 output = _resample(  # resample rgb channels
#     514                     self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#     515                 output[..., 3] = output_alpha  # recombine rgb and alpha
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     161
#     162
# --> 163 def _resample(
#     164         image_obj, data, out_shape, transform, *, resample=None, alpha=1):
#     165     """
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7c38833a4b80> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2153                 # so that we can inject the orientation
#    2154                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155                     self.figure.draw(renderer)
#    2156             if bbox_inches:
#    2157                 if bbox_inches == "tight":
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3179             _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
#    3180
# -> 3181         mimage._draw_list_compositing_images(
#    3182             renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3183
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in draw(self, renderer)
#     597                 renderer.draw_image(gc, l, b, im, trans)
#     598         else:
# --> 599             im, l, b, trans = self.make_image(
#     600                 renderer, renderer.get_image_magnification())
#     601             if im is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     900         clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     901                 else self.get_figure(root=True).bbox)
# --> 902         return self._make_image(self._A, bbox, transformed_bbox, clip,
#     903                                 magnification, unsampled=unsampled)
#     904
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     501                 if A.ndim == 2:  # interpolation_stage = 'rgba'
#     502                     self.norm.autoscale_None(A)
# --> 503                     A = self.to_rgba(A)
#     504                 alpha = self._get_scalar_alpha()
#     505                 if A.shape[2] == 3:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/colorizer.py in to_rgba(self, x, alpha, bytes, norm)
#     354
#     355         """
# --> 356         return self._colorizer.to_rgba(x, alpha=alpha, bytes=bytes, norm=norm)
#     357
#     358     def get_clim(self):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/colorizer.py in to_rgba(self, x, alpha, bytes, norm)
#     156         if norm:
#     157             x = self.norm(x)
# --> 158         rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     159         return rgba
#     160
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py in __call__(self, X, alpha, bytes)
#     737         RGBA values with a shape of ``X.shape + (4, )``.
#     738         """
# --> 739         rgba, mask = self._get_rgba_and_mask(X, alpha=alpha, bytes=bytes)
#     740         if not np.iterable(X):
#     741             rgba = tuple(rgba)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py in _get_rgba_and_mask(self, X, alpha, bytes)
#     783         mask_over = xa >= self.N
#     784         # If input was masked, get the bad mask from it; else mask out nans.
# --> 785         mask_bad = X.mask if np.ma.is_masked(X) else np.isnan(xa)
#     786         with np.errstate(invalid="ignore"):
#     787             # We need this cast for unsigned ints as well as floats
#
# /usr/local/lib/python3.11/dist-packages/numpy/ma/core.py in is_masked(x)
#    6794
#    6795
# -> 6796 def is_masked(x):
#    6797     """
#    6798     Determine whether input has masked values.
#
# KeyboardInterrupt:

# %% [markdown]
# For texture anaysis and shape features of the images, we applied Edge Detection and Texture Extraction using a technique called Local Binary Patterns (LBP):
#
# - Starting with the shape, we percieve clear and distinguishable outlines in most of our image shapes, and which reflects the presence of a few images with complex or Noisy backgrounds.
# - The texture of the images is variate, as the shells image show a consistent texture pattern, while other images have more "sparse" texture details.

# %% [markdown]
# # Prepare Data

# %%
#general configurations
DATA_PATH = "/content/rare_species"
IMG_SIZE = (224, 224)
BATCH_SIZE = 128
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

# we define the mean and the std deviation for RGB
IMAGENET_MEAN = tf.constant([0.485, 0.456, 0.406], dtype=tf.float32)
IMAGENET_STD = tf.constant([0.229, 0.224, 0.225], dtype=tf.float32)

# %%
# we define a function to eliminate low quality images
def is_valid_image(path, min_resolution=(100, 100)):
    try:
        img = Image.open(path)
        return img.size[0] >= min_resolution[0] and img.size[1] >= min_resolution[1]
    except:
        return False

def load_and_clean_metadata(data_path):
    metadata = pd.read_csv(os.path.join(data_path, 'metadata.csv'))
    metadata['full_path'] = metadata['file_path'].apply(lambda x: os.path.join(data_path, x))
    metadata['valid'] = metadata['full_path'].apply(lambda x: os.path.exists(x) and is_valid_image(x))
    return metadata[metadata['valid'] == True]

# %%
# analisar familias com menos imagens
def analyze_classes(metadata):
    family_counts = metadata['family'].value_counts()
    plt.figure(figsize=(14, 6))
    sns.histplot(family_counts, bins=50, kde=False)
    plt.title("distribution of images per family")
    plt.xlabel("number of images")
    plt.ylabel("number of families")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    print("Families above 10 images:")
    print(family_counts[family_counts < 10])

# %%
def prepare_datasets_cleaned(metadata):
    file_paths = metadata['full_path'].values
    family_labels = metadata['family'].values
    phylum_labels = metadata['phylum'].values

    # Split into train, temp (val+test)
    train_paths, temp_paths, train_families, temp_families, train_phyla, temp_phyla = train_test_split(
        file_paths, family_labels, phylum_labels,
        test_size=0.3, stratify=family_labels, random_state=SEED
    )

    # Split temp into val and test
    val_paths, test_paths, val_families, test_families, val_phyla, test_phyla = train_test_split(
        temp_paths, temp_families, temp_phyla,
        test_size=0.5, stratify=temp_families, random_state=SEED
    )

    # Create lookup tables
    family_lookup = tf.keras.layers.StringLookup(num_oov_indices=1, output_mode='int')
    family_lookup.adapt(train_families)
    phylum_lookup = tf.keras.layers.StringLookup(num_oov_indices=1, output_mode='int')
    phylum_lookup.adapt(train_phyla)

    def make_ds(paths, families, phyla):
        return tf.data.Dataset.from_tensor_slices((paths, families, phyla))

    train_ds = make_ds(train_paths, train_families, train_phyla)
    val_ds = make_ds(val_paths, val_families, val_phyla)
    test_ds = make_ds(test_paths, test_families, test_phyla)

    # Preprocessing function
    def preprocess(file_path, family, phylum):
        img = tf.io.read_file(file_path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, IMG_SIZE)
        img = img / 255.0
        img = (img - IMAGENET_MEAN) / IMAGENET_STD
        img = tf.ensure_shape(img, [224, 224, 3])
        phylum_idx = phylum_lookup(phylum)
        family_idx = family_lookup(family)
        return (img, phylum_idx), family_idx

    # Augmentation for train only
    def augment(image_phylum, label):
        image, phylum = image_phylum
        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_brightness(image, max_delta=0.3)
        image = tf.image.rot90(image, tf.random.uniform([], 0, 4, dtype=tf.int32))
        return (image, phylum), label

    # Prepare datasets
    train_ds = train_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.shuffle(1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    val_ds = val_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    val_ds = val_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    test_ds = test_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    test_ds = test_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    return train_ds, val_ds, test_ds, family_lookup, phylum_lookup, train_families, val_families, test_families

# %%
metadata = load_and_clean_metadata(DATA_PATH)
analyze_classes(metadata)

train_ds, val_ds, test_ds, family_lookup, phylum_lookup, train_fams, val_fams, test_fams = prepare_datasets_cleaned(metadata)

NUM_FAMILIES = len(family_lookup.get_vocabulary())
NUM_PHYLA = len(phylum_lookup.get_vocabulary())
# Out:
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3442: DecompressionBombWarning: Image size (115600000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# Families above 10 images:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# #Models

# %% [markdown]
# We start by defining the models that we want to test

# %%
# pretrained models
def build_pretrained_model(base_model, name, num_phyla, num_families):
    base_model.trainable = False
    image_input = tf.keras.Input(shape=(224, 224, 3), name="image")
    phylum_input = tf.keras.Input(shape=(), dtype=tf.int32, name="phylum")

    x = base_model(image_input, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    phylum_embed = tf.keras.layers.Embedding(input_dim=num_phyla, output_dim=16)(phylum_input)
    phylum_embed = tf.keras.layers.Flatten()(phylum_embed)

    x = tf.keras.layers.Concatenate()([x, phylum_embed])
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    output = tf.keras.layers.Dense(num_families, activation='softmax')(x)

    return tf.keras.Model(inputs=[image_input, phylum_input], outputs=output, name=name)

model_vgg16 = build_pretrained_model(
    tf.keras.applications.VGG16(include_top=False, weights="imagenet", input_shape=(224, 224, 3)),
    "VGG16_Model", NUM_PHYLA, NUM_FAMILIES)

model_resnet = build_pretrained_model(
    tf.keras.applications.ResNet152(include_top=False, weights="imagenet", input_shape=(224, 224, 3)),
    "ResNet152_Model", NUM_PHYLA, NUM_FAMILIES)

model_efficient = build_pretrained_model(
    tf.keras.applications.EfficientNetB7(include_top=False, weights="imagenet", input_shape=(224, 224, 3)),
    "EfficientNetB7_Model", NUM_PHYLA, NUM_FAMILIES)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
def build_custom_cnn(num_phyla, num_families):
    img_input = tf.keras.Input(shape=(224, 224, 3), name="image")
    phylum_input = tf.keras.Input(shape=(), dtype=tf.int32, name="phylum")

    x = tf.keras.layers.Conv2D(32, 3, activation='relu', padding='same')(img_input)
    x = tf.keras.layers.MaxPooling2D()(x)
    x = tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same')(x)
    x = tf.keras.layers.MaxPooling2D()(x)
    x = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(x)
    x = tf.keras.layers.Flatten()(x)

    phylum_embed = tf.keras.layers.Embedding(input_dim=num_phyla, output_dim=16)(phylum_input)
    phylum_embed = tf.keras.layers.Flatten()(phylum_embed)

    concat = tf.keras.layers.Concatenate()([x, phylum_embed])
    x = tf.keras.layers.Dense(256, activation='relu')(concat)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    output = tf.keras.layers.Dense(num_families, activation='softmax')(x)

    return tf.keras.Model(inputs=[img_input, phylum_input], outputs=output, name="CustomCNN")

# %% [markdown]
# # check one models' performance at a time

# %%
#model = VGG16_Model  # Ou outro modelo que deseje testar
#model.compile(
#    optimizer=tf.keras.optimizers.Adam(1e-3),
#    loss="sparse_categorical_crossentropy",
#    metrics=["accuracy"]
#)

#history = model.fit(
#    train_ds,
#    validation_data=val_ds,
#    epochs=20,
#    callbacks=[
#        tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
#    ]
#)

# %%
#plt.plot(history.history['accuracy'], label='train acc')
#plt.plot(history.history['val_accuracy'], label='val acc')
#plt.legend()
#plt.title("Accuracy per epoch")
#plt.show()

# %%
#model = model_efficient  # Ou outro modelo que deseje testar
#model.compile(
#    optimizer=tf.keras.optimizers.Adam(1e-3),
#    loss="sparse_categorical_crossentropy",
#    metrics=["accuracy"]
#)

#history = model.fit(
#    train_ds,
#    validation_data=val_ds,
#    epochs=20,
#    callbacks=[
#        tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
#    ]
#)

# %%
#plt.plot(history.history['accuracy'], label='train acc')
#plt.plot(history.history['val_accuracy'], label='val acc')
#plt.legend()
#plt.title("Accuracy per epoch")
#plt.show()

# %%
#model = model_resnet  # Ou outro modelo que deseje testar
#model.compile(
#    optimizer=tf.keras.optimizers.Adam(1e-3),
#    loss="sparse_categorical_crossentropy",
#    metrics=["accuracy"]
#)

#history = model.fit(
#    train_ds,
#    validation_data=val_ds,
#    epochs=20,
#    callbacks=[
#        tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
#    ]
#)

# %%
#plt.plot(history.history['accuracy'], label='train acc')
#plt.plot(history.history['val_accuracy'], label='val acc')
#plt.legend()
#plt.title("Accuracy per epoch")
#plt.show()

# %% [markdown]
# #Run all models in a loop

# %%
def get_predictions_and_labels(model, val_ds):
    y_true = []
    y_pred_probs = []

    # from val data
    for (img, phylum), label in val_ds.unbatch():
        # calculate the prediction
        pred = model.predict([img[None, ...], phylum[None, ...]], verbose=0)
        y_pred_probs.append(pred[0])  # Probability for each class
        y_true.append(label.numpy())  # real label

    return np.array(y_true), np.array(y_pred_probs)

# %%
def plot_roc_auc(y_true, y_pred_probs, num_classes, model_name):
    # we binarize labels for the auc curve (false positives and true positives)
    y_true_bin = label_binarize(y_true, classes=np.arange(num_classes))

    # create dictionnaires for false positive true positive and the roc auc curve
    fpr = {}
    tpr = {}
    roc_auc = {}

    # Calcule ROC for each class
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Calculate the average macro AUC
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(num_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
    mean_tpr /= num_classes
    mean_auc = auc(all_fpr, mean_tpr)

    # # AUC ROC plot
    # plt.figure(figsize=(8, 12))
    # plt.plot(all_fpr, mean_tpr, label=f'Macro-average ROC (AUC = {mean_auc:.2f})', linestyle='--')
    # for i in range(num_classes):
    #     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})', alpha=0.3)

    # plt.plot([0, 1], [0, 1], 'k--')
    # plt.xlabel('False Positive Rate')
    # plt.ylabel('True Positive Rate')
    # plt.title(f'ROC Curve pour {model_name}')
    # plt.legend(loc='best')
    # plt.grid(True)
    # plt.show()

    return mean_auc

# %%
#F1 score definition
def compute_f1_score(y_true, y_pred_probs):
    y_pred = np.argmax(y_pred_probs, axis=1)
    f1 = f1_score(y_true, y_pred, average='weighted')
    return f1

# %%
# List of the models to try
models = [
    model_vgg16
]

# Stock results
results = {}

# Loop to train each model
for model in models:
    print(f"\nTraining the model : {model.name}\n")

    # Compile
    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
        jit_compile=True
    )

    # Train the model
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=50,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
        ]
    )

    # Stock train results
    results[model.name] = history.history

    # Accuracy plot
    plt.plot(history.history['accuracy'], label='train acc')
    plt.plot(history.history['val_accuracy'], label='val acc')
    plt.legend()
    plt.title(f"Accuracy for {model.name}")
    plt.show()

    # Validation metrics
    y_val_true, y_val_pred_probs = get_predictions_and_labels(model, val_ds)
    mean_auc_val = plot_roc_auc(y_val_true, y_val_pred_probs, NUM_FAMILIES, model.name)
    f1_val = compute_f1_score(y_val_true, y_val_pred_probs)
    print(f"Validation AUC (macro-average) for {model.name}: {mean_auc_val:.2f}")
    print(f"Validation F1 Score (weighted) for {model.name}: {f1_val:.2f}")

    # ✅ Test metrics
    y_test_true, y_test_pred_probs = get_predictions_and_labels(model, test_ds)
    mean_auc_test = plot_roc_auc(y_test_true, y_test_pred_probs, NUM_FAMILIES, model.name + "_Test")
    f1_test = compute_f1_score(y_test_true, y_test_pred_probs)
    print(f"✅ Test AUC (macro-average) for {model.name}: {mean_auc_test:.2f}")
    print(f"✅ Test F1 Score (weighted) for {model.name}: {f1_test:.2f}")
# Out:
# Training the model : VGG16_Model
#
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 234s 3s/step - accuracy: 0.0422 - loss: 5.0495 - val_accuracy: 0.1285 - val_loss: 4.7473
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 235s 3s/step - accuracy: 0.1045 - loss: 4.6684 - val_accuracy: 0.1608 - val_loss: 4.1629
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - accuracy: 0.1511 - loss: 4.1216 - val_accuracy: 0.2076 - val_loss: 3.6353
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - accuracy: 0.1768 - loss: 3.7200 - val_accuracy: 0.2187 - val_loss: 3.3925
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 266s 3s/step - accuracy: 0.2088 - loss: 3.4572 - val_accuracy: 0.2627 - val_loss: 3.1825
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 214s 3s/step - accuracy: 0.2254 - loss: 3.3001 - val_accuracy: 0.2844 - val_loss: 3.0404
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.2472 - loss: 3.1515 - val_accuracy: 0.2866 - val_loss: 2.9345
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.2699 - loss: 3.0110 - val_accuracy: 0.3111 - val_loss: 2.8547
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - accuracy: 0.2804 - loss: 2.9209 - val_accuracy: 0.3339 - val_loss: 2.7608
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 209s 3s/step - accuracy: 0.2968 - loss: 2.8286 - val_accuracy: 0.3439 - val_loss: 2.7181
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 197s 3s/step - accuracy: 0.3145 - loss: 2.7538 - val_accuracy: 0.3484 - val_loss: 2.6518
# Epoch 12/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 212s 3s/step - accuracy: 0.3249 - loss: 2.6764 - val_accuracy: 0.3517 - val_loss: 2.6195
# Epoch 13/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 200s 3s/step - accuracy: 0.3382 - loss: 2.6539 - val_accuracy: 0.3656 - val_loss: 2.5909
# Epoch 14/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 200s 3s/step - accuracy: 0.3489 - loss: 2.5730 - val_accuracy: 0.3740 - val_loss: 2.5371
# Epoch 15/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.3653 - loss: 2.4868 - val_accuracy: 0.3767 - val_loss: 2.5129
# Epoch 16/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 212s 3s/step - accuracy: 0.3672 - loss: 2.4676 - val_accuracy: 0.3901 - val_loss: 2.4870
# Epoch 17/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 214s 3s/step - accuracy: 0.3819 - loss: 2.4177 - val_accuracy: 0.3945 - val_loss: 2.4613
# Epoch 18/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.3991 - loss: 2.3437 - val_accuracy: 0.4129 - val_loss: 2.4373
# Epoch 19/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 262s 3s/step - accuracy: 0.3969 - loss: 2.3157 - val_accuracy: 0.4001 - val_loss: 2.4207
# Epoch 20/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.4017 - loss: 2.2868 - val_accuracy: 0.4051 - val_loss: 2.4259
# Epoch 21/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 216s 3s/step - accuracy: 0.4132 - loss: 2.2410 - val_accuracy: 0.4035 - val_loss: 2.4184
# Epoch 22/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.4271 - loss: 2.2317 - val_accuracy: 0.4023 - val_loss: 2.3787
# Epoch 23/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 216s 3s/step - accuracy: 0.4330 - loss: 2.1755 - val_accuracy: 0.4185 - val_loss: 2.3679
# Epoch 24/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 215s 3s/step - accuracy: 0.4327 - loss: 2.1484 - val_accuracy: 0.4201 - val_loss: 2.3563
# Epoch 25/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 248s 3s/step - accuracy: 0.4396 - loss: 2.1441 - val_accuracy: 0.4129 - val_loss: 2.3404
# Epoch 26/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 206s 3s/step - accuracy: 0.4428 - loss: 2.1000 - val_accuracy: 0.4252 - val_loss: 2.3388
# Epoch 27/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.4543 - loss: 2.0515 - val_accuracy: 0.4263 - val_loss: 2.3309
# Epoch 28/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 215s 3s/step - accuracy: 0.4599 - loss: 2.0423 - val_accuracy: 0.4302 - val_loss: 2.3163
# Epoch 29/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 217s 3s/step - accuracy: 0.4632 - loss: 1.9879 - val_accuracy: 0.4307 - val_loss: 2.3024
# Epoch 30/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 204s 3s/step - accuracy: 0.4723 - loss: 1.9983 - val_accuracy: 0.4346 - val_loss: 2.3033
# Epoch 31/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 272s 3s/step - accuracy: 0.4880 - loss: 1.9380 - val_accuracy: 0.4480 - val_loss: 2.2925
# Epoch 32/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 261s 3s/step - accuracy: 0.4853 - loss: 1.9066 - val_accuracy: 0.4263 - val_loss: 2.3021
# Epoch 33/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 215s 3s/step - accuracy: 0.4912 - loss: 1.8838 - val_accuracy: 0.4357 - val_loss: 2.2984
# Epoch 34/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 248s 3s/step - accuracy: 0.4952 - loss: 1.8752 - val_accuracy: 0.4363 - val_loss: 2.2863
# Epoch 35/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 214s 3s/step - accuracy: 0.4916 - loss: 1.8885 - val_accuracy: 0.4341 - val_loss: 2.2786
# Epoch 36/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.5096 - loss: 1.8048 - val_accuracy: 0.4407 - val_loss: 2.2606
# Epoch 37/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 262s 3s/step - accuracy: 0.4943 - loss: 1.8257 - val_accuracy: 0.4441 - val_loss: 2.2735
# Epoch 38/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 248s 3s/step - accuracy: 0.5161 - loss: 1.7939 - val_accuracy: 0.4368 - val_loss: 2.2790
# Epoch 39/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 203s 3s/step - accuracy: 0.5163 - loss: 1.7807 - val_accuracy: 0.4446 - val_loss: 2.2677
# Epoch 40/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 261s 3s/step - accuracy: 0.5194 - loss: 1.7434 - val_accuracy: 0.4457 - val_loss: 2.2676
# Epoch 41/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 270s 3s/step - accuracy: 0.5224 - loss: 1.7559 - val_accuracy: 0.4474 - val_loss: 2.2841
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Validation AUC (macro-average) for VGG16_Model: nan
# Validation F1 Score (weighted) for VGG16_Model: 0.41
# ✅ Test AUC (macro-average) for VGG16_Model: nan
# ✅ Test F1 Score (weighted) for VGG16_Model: 0.41
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(

# %%
import numpy as np
import pandas as pd

# Count how often each class appears in y_test_true
unique, counts = np.unique(y_test_true, return_counts=True)
top_indices = np.argsort(counts)[-30:]  # Top 30 most frequent classes

# Filter the confusion matrix
filtered_cm = cm[np.ix_(top_indices, top_indices)]
filtered_labels = np.array(family_lookup.get_vocabulary())[top_indices]

# Plot it again
disp = ConfusionMatrixDisplay(confusion_matrix=filtered_cm, display_labels=filtered_labels)
fig, ax = plt.subplots(figsize=(10, 10))
disp.plot(ax=ax, xticks_rotation='vertical', cmap='Blues')
plt.title(f"Top 30 Confusion Matrix - {model.name}")
plt.show()
